# %% [markdown]
# ## Collect a Company's Patent Porfolio
#
# This notebook will attempt to amass, for any given company, their entire worldwide patent porfolio.\*
#
# ### U.S. Portfolio
#
# Collecting their U.S. portfolio will proceed in a few steps:
#
# 1. Collect all applications ever assigned to the company
#
#     a. Those applications naming the company as an applicant
#     b. Those assigned to the company via an assignment
#
# 2. Prune all applications assigned out of the company, as recorded in USPTO assignment records
#
# \*NOTE: I say "attempt" because the notebook relies on the USPTO system, and the International Patent Document (INPADOC) service. Not all foreign jurisdictions participate in INPADOC, and not all INPADOC member states are as good at contributing to the system as we would like. So coverage is good, but not perfect.

# %% [markdown]
# First, we do our standard imports, and grab the USApplication and Assignment objects from patent_client

# %%
import pandas as pd
from patent_client import USApplication, Assignment

company_name = 'Avid Technology'

# %% [markdown]
# ### Step 0: Confirm that the search retreives the correct company's applications

# %%
Assignment.objects.filter(assignee=company_name).values_list("pat_assignee_name", flat=True)[:30]
# Out:
# ['AVID TECHNOLOGY LIMITED',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  ['AVID TECHNOLOGY INC.', 'AVID SYSTEMS, INC.'],
#  ['AVID TECHNOLOGY INC.', 'AVID SYSTEMS, INC.'],
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.',
#  'AVID TECHNOLOGY, INC.']

# %% [markdown]
# ### Step 1.a: Collect all applications naming the company as applicant

# %%
applicant_apps = USApplication.objects.filter(first_named_applicant=company_name).values_list('appl_id', flat=True)
len(applicant_apps)
# Out:
# ---------------------------------------------------------------------------
# NotAvailableException                     Traceback (most recent call last)
# <ipython-input-3-5917ca27028d> in <module>
#       1 applicant_apps = USApplication.objects.filter(first_named_applicant=company_name).values_list('appl_id', flat=True)
# ----> 2 len(applicant_apps)
#
# ~/Projects/patent_client/src/patent_client/uspto_peds.py in __len__(self)
#      48
#      49     def __len__(self):
# ---> 50         return self.get_page(0)["numFound"]
#      51
#      52     def get_page(self, page_number):
#
# ~/Projects/patent_client/src/patent_client/uspto_peds.py in get_page(self, page_number)
#      55             response = session.post(QUERY_URL, json=query_params)
#      56             if not response.ok:
# ---> 57                 if self.is_online():
#      58                     raise HttpException(
#      59                         f"{response.status_code}\n{response.text}\n{response.headers}\n{query_params}"
#
# ~/Projects/patent_client/src/patent_client/uspto_peds.py in is_online(self)
#     128                 raise NotAvailableException("The Patent Examination Data API is Broken! - this is a USPTO problem")
#     129             else:
# --> 130                 raise NotAvailableException("There is a USPTO problem")
#     131
#     132     @property
#
# NotAvailableException: There is a USPTO problem

# %% [markdown]
# ### Step 1.b: Collect all applications assigned to the company

# %%
from itertools import chain
# The assigned apps is either a single value, or a list of values if more than one property was assigned

assigned_apps = [a.appl_id for a in chain.from_iterable(Assignment.objects.filter(assignee=company_name).values_list("properties", flat=True))]
len(set(assigned_apps))

# %% [markdown]
# And now we combine the two

# %%
all_apps = list(applicant_apps) + assigned_apps
all_apps = list(set(all_apps)) # use set to deduplicate the list

print(f'Total U.S. Applications Ever Owned by {company_name}: {len(all_apps)}')

# %% [markdown]
# ### Step 2: Collect all applications ever assigned out of the company

# %%
assignments_out = Assignment.objects.filter(assignor=company_name)
assigned_out_apps = list()

for assignment in assignments_out:
    if 'assignors interest' in assignment.conveyance_text.lower():
        a = assignment.appl_num
        if isinstance(a, list):
            assigned_out_apps += a
        else:
            assigned_out_apps.append(a)
            
len(assigned_out_apps)
# Out:
# 48

# %% [markdown]
# ### Step 3: Subtract one set from the other

# %%
owned_apps = list(set(all_apps) - set(assigned_out_apps))
len(owned_apps)
# Out:
# 314

# %%
n_apps = owned_apps

# %% [markdown]
# ### Step 4: Generate status report

# %%
import pandas as pd
from patent_client.parser import parse

apps = USApplication.objects.filter(appl_id=owned_apps)

df = pd.DataFrame.from_records(apps.values(
    'appl_id', 
    'app_filing_date', 
    'app_early_pub_number',
    'app_early_pub_date',
    'patent_number',
    'patent_issue_date',
    'patent_title',
    'inventors__0__name',
    'applicants__0__name_line_one',
    'app_status',
    'app_status_date',
    'expiration__date',
    'expiration__parent_appl_id',
    'expiration__parent_app_filing_date',
    'expiration__pta_or_pte',
    'expiration__terminal_disclaimer_filed'
))

def display_num(number):
    if number:
        return parse(number).display()
    else:
        return number

#df['patent_title'] = df['patent_title'].apply(str.capitalize)
#df['appl_id'] = df['appl_id'].apply(display_num)
#df['app_early_pub_number'] = df['app_early_pub_number'].apply(display_num)
#df['patent_number'] = df['patent_number'].apply(display_num)
us_df = df
us_df.head()
# Out:
# > /Users/parkerhancock/Projects/patent_client/src/patent_client/uspto_peds.py(131)is_online()
# -> raise NotAvailableException("There is a USPTO problem")

# %%
from collections import defaultdict
from itertools import chain

assignments = chain(Assignment.objects.filter(assignee=company_name), Assignment.objects.filter(assignor=company_name))

# Create a reverse index of the Assignments out by application number
assignment_index = defaultdict(set)
for assignment in assignments:
    for p in assignment.properties:
        us_app = p.us_application
        for parent in us_app.parents:
            assignment_index[parent.parent_appl_id].add(assignment)
        for child in us_app.children:
            assignment_index[child.child_appl_id].add(assignment)
        assignment_index[p.appl_id].add(assignment)

# Sort each entry in reverse chronological order, and filter out security interests
for appl_id, assignments in assignment_index.items():
    assignments = filter(lambda x: "security" not in x.conveyance_text.lower(), assignments)
    assignments = sorted(assignments, key=lambda x: x.recorded_date, reverse=True)
    assignment_index[appl_id] = list(assignments)

# %%
def annotate_with_assignments(row):
    assignments = assignment_index[row['appl_id']]
    if len(assignments):
        assignment = assignments[0]
        assignment_data = pd.Series(dict(
            current_assignee=assignment.pat_assignee_name,
            reel_frame=assignment.id,
            conveyance_type=assignment.conveyance_text,
            assignment_date=assignment.recorded_date
        ))
        return row.append(assignment_data)
    return row

us_df = us_df.apply(annotate_with_assignments, axis=1)[list(us_df.columns) + ['current_assignee', 'reel_frame', 'assignment_date', 'conveyance_type']]
us_df
# Out:
#            appl_id app_filing_date app_early_pub_number app_early_pub_date  \
# 0         15806826      2017-11-08      US20180128073A1         2018-05-10
# 1         16109233      2018-08-22      US20180363415A1         2018-12-20
# 2         15189090      2016-06-22      US20170030161A1         2017-02-02
# 3         16265808      2019-02-01      US20190169951A1         2019-06-06
# 4         15697572      2017-09-07      US20180010413A1         2018-01-11
# 5         15654156      2017-07-19      US20170314363A1         2017-11-02
# 6         16274906      2019-02-13      US20190178045A1         2019-06-13
# 7         14922969      2015-10-26      US20160115753A1         2016-04-28
# 8         16211847      2018-12-06      US20190169953A1         2019-06-06
# 9         62625099      2018-02-01                 None               None
# 10        62625111      2018-02-01                 None               None
# 11        62595299      2017-12-06                 None               None
# 12  PCT/US15/37636      2015-06-25                 None               None
# 13        16164456      2018-10-18      US20190063178A1         2019-02-28
# 14        16182206      2018-11-06      US20190078414A1         2019-03-14
# 15        16040132      2018-07-19      US20180324026A1         2018-11-08
# 16        16028047      2018-07-05      US20190010774A1         2019-01-10
# 17        62573982      2017-10-18                 None               None
# 18        15962607      2018-04-25      US20180363409A1         2018-12-20
# 19        15218457      2016-07-25      US20170022783A1         2017-01-26
# 20        15588608      2017-05-06      US20170241233A1         2017-08-24
# 21        62406195      2016-10-10                 None               None
# 22        15672790      2017-08-09      US20170370176A1         2017-12-28
# 23        62372550      2016-08-09                 None               None
# 24        13245496      2011-09-26      US20120006532A1         2012-01-12
# 25        62253748      2015-11-11                 None               None
# 26        13999329      2014-02-10      US20140224476A1         2014-08-14
# 27        13134819      2011-06-17      US20120318507A1         2012-12-20
# 28        13373223      2011-11-08      US20130112412A1         2013-05-09
# 29        13893195      2013-05-13      US20130240201A1         2013-09-19
# 30        13194877      2011-07-29      US20110290473A1         2011-12-01
# 31        16259910      2019-01-28      US20190234180A1         2019-08-01
# 32        62622678      2018-01-26                 None               None
#
#    patent_number patent_issue_date  \
# 0           None              None
# 1           None              None
# 2       10352125        2019-07-16
# 3           None              None
# 4           None              None
# 5           None              None
# 6           None              None
# 7           None              None
# 8           None              None
# 9           None              None
# 10          None              None
# 11          None              None
# 12          None              None
# 13          None              None
# 14          None              None
# 15          None              None
# 16          None              None
# 17          None              None
# 18          None              None
# 19      10107070        2018-10-23
# 20       9850736        2017-12-26
# 21          None              None
# 22          None              None
# 23          None              None
# 24       9562415        2017-02-07
# 25          None              None
# 26       9441448        2016-09-13
# 27       9428988        2016-08-30
# 28       9388662        2016-07-12
# 29       9181772        2015-11-10
# 30       9062522        2015-06-23
# 31          None              None
# 32          None              None
#
#                                          patent_title inventors__0__name  \
# 0   POWDER METAL GRIPPING ELEMENTS FOR SETTABLE DO...               None
# 1   DOWNHOLE ASSEMBLY FOR SELECTIVELY SEALING OFF ...               None
# 2   DOWNHOLE PLUG HAVING DISSOLVABLE METALLIC AND ...               None
# 3      EXTENDED REACH PLUG HAVING DEGRADABLE ELEMENTS               None
# 4                              PLUG OF EXTENDED REACH               None
# 5   DOWNHOLE ASSEMBLY FOR SELECTIVELY SEALING OFF ...               None
# 6   ELECTRICALLY POWERED SETTING TOOL AND PERFORAT...               None
# 7   ELECTRICALLY POWERED SETTING TOOL AND PERFORAT...               None
# 8            MOLDED DEGRADABLE DOWNHOLE TOOL ELEMENTS               None
# 9   INSERTS FOR INJECTION MOLDED DEGRADABLE DOWNHO...               None
# 10     EXTENDED REACH PLUG HAVING DEGRADABLE ELEMENTS               None
# 11  INSERTS FOR INJECTION MOLDED DEGRADABLE DOWNHO...               None
# 12                 DISSOLVABLE ALUMINUM DOWNHOLE PLUG               None
# 13  SPLIT RING SLIPS , SLOTTED UNIBODY SLIPS, MULT...               None
# 14                 DISSOLVABLE ALUMINUM DOWNHOLE PLUG               None
# 15     INTERVENTIONLESS FRANGIBLE DISK ISOLATION TOOL               None
# 16  ELECTRICALLY POWERED SETTING TOOL AND PERFORAT...               None
# 17  SPLIT RING SLIPS, SLOTTED UNIBODY SLIPS, MULTI...               None
# 18  DISSOLVABLE DOWNHOLE FRAC TOOL HAVING A SINGLE...               None
# 19     INTERVENTIONLESS FRANGIBLE DISK ISOLATION TOOL               None
# 20                                EXTENDED REACH PLUG               None
# 21  DISSOLVABLE DOWNHOLE TOOL COMPRISING BOTH DEGR...               None
# 22                      SPLIT RING SEALING ASSEMBLIES               None
# 23                          SPLIT RING SEALING PETALS               None
# 24            CONFIGURABLE INSERTS FOR DOWNHOLE PLUGS               None
# 25  Downhole Isolation Tool With Degradable Polyme...               None
# 26  DOWN HOLE TOOL HAVING IMPROVED SEGMENTED BACK ...               None
# 27  Hydrocarbon well and technique for perforating...               None
# 28                      SETTABLE WELL TOOL AND METHOD               None
# 29        DECOMPOSABLE IMPEDIMENTS FOR DOWNHOLE PLUGS               None
# 30            CONFIGURABLE INSERTS FOR DOWNHOLE PLUGS               None
# 31           GAS CAPABLE FRANGIBLE DISC BARRIER VALVE               None
# 32             GAS CAPABLE CERAMIC DISC BARRIER VALVE               None
#
#                applicants__0__name_line_one  \
# 3   ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 4   ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 5   ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 6   ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 7   ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 8   ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 9   ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 10  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 11  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 12  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 13  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 14  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 15  CORRECTIVE ASSIGNMENT TO CORRECT THE ASSIGNEE'...
# 16  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 17  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 18  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 19  CORRECTIVE ASSIGNMENT TO CORRECT THE ASSIGNEE'...
# 20  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 21  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 22  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 23  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 24  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 25  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 26  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 27  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 28  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 29  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 30  ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT...
# 31                                                NaN
# 32                                                NaN

# %% [markdown]
# ### Foreign Patent Portfolio
#
# Now we will fetch the company's wordwide portfolio, as it appears in the Inpadoc system maintained by the EPO

# %%
from patent_client import Inpadoc
from patent_client.util import values_iterator

foreign = (p.document for p in Inpadoc.objects.filter(applicant=company_name) if p.country != "US")
values = ('country', 'application', 'publication', 'publication_date', 'title', 'applicants__0', 'inventors__0', 'legal__-1__description', 'legal__-1__date')
foreign_df = pd.DataFrame.from_records(values_iterator(foreign, *values))
foreign_df['title'] = foreign_df['title'].apply(lambda x: x.capitalize() if x else None)
foreign_df['status'] = foreign_df['legal__-1__description']
foreign_df['status_date'] = foreign_df['legal__-1__date']
foreign_df = foreign_df.drop(labels=['legal__-1__description', 'legal__-1__date'], axis=1)
foreign_df
# Out:
#    country   application     publication publication_date  \
# 0       WO  US2019015461  WO2019148128A1       2019-08-01
# 1       CA     CA3026847     CA3026847A1       2019-06-06
# 2       CA     CA3021453     CA3021453A1       2019-04-18
# 3       CA     CA3035430     CA3035430A1       2014-06-26
# 4       CA     CA2985278     CA2985278A1       2018-05-08
# 5       CA     CA2975842     CA2975842A1       2018-02-09
# 6       CA     CA2937076     CA2937076A1       2017-01-24
# 7       CA     CA2935508     CA2935508A1       2015-10-02
# 8       CA     CA2910136     CA2910136A1       2016-04-24
# 9       WO  US2015037636  WO2016003759A1       2016-01-07
# 10      CA     CA2886988     CA2886988A1       2015-10-02
#
#                                                 title  \
# 0            Gas capable frangible disc barrier valve
# 1            Molded degradable downhole tool elements
# 2   Split ring slips, slotted unibody slips, multi...
# 3   Downhole tools having non-toxic degradable ele...
# 4   Powder metal gripping elements for settable do...
# 5                       Split ring sealing assemblies
# 6      Interventionless frangible disk isolation tool
# 7   Downhole plug having dissolvable metallic and ...
# 8   Electrically powered setting tool and perforat...
# 9                  Dissolvable aluminum downhole plug
# 10                 Dissolvable aluminum downhole plug
#
#                           applicants__0         inventors__0  \
# 0   MAGNUM OIL TOOLS INTERNATIONAL, LTD         FRAZIER, W,
# 1   MAGNUM OIL TOOLS INTERNATIONAL, LTD     FRAZIER, W. LYNN
# 2   MAGNUM OIL TOOLS INTERNATIONAL, LTD     FRAZIER, W. LYNN
# 3   MAGNUM OIL TOOLS INTERNATIONAL, LTD   FRAZIER, DERRICK,
# 4   MAGNUM OIL TOOLS INTERNATIONAL, LTD     FRAZIER, W. LYNN
# 5   MAGNUM OIL TOOLS INTERNATIONAL, LTD     FRAZIER, W. LYNN
# 6   MAGNUM OIL TOOLS INTERNATIONAL, LLC      YONG, LAKHENA,
# 7   MAGNUM OIL TOOLS INTERNATIONAL, LTD     FRAZIER, W. LYNN
# 8   MAGNUM OIL TOOLS INTERNATIONAL, LTD  FRAZIER, W., LYNN,
# 9   MAGNUM OIL TOOLS INTERNATIONAL, LTD    FRAZIER, W., LYNN
# 10  MAGNUM OIL TOOLS INTERNATIONAL, LTD     FRAZIER, W. LYNN
#
#                                              status status_date
# 0                                              None        None
# 1                                              None        None
# 2                                              None        None
# 3                               EXAMINATION REQUEST  2019-03-14
# 4                                              None        None
# 5                                              None        None
# 6                               EXAMINATION REQUEST  2018-11-28
# 7                               EXAMINATION REQUEST  2019-01-28
# 8                                              None        None
# 9   EP: PCT APPLICATION NON-ENTRY IN EUROPEAN PHASE  2017-07-26
# 10                                             None        None

# %% [markdown]
# And now, a status report:

# %% [markdown]
# And now we will take our results, and write to an excel file

# %%
writer = pd.ExcelWriter(f'{company_name}_portfolio.xlsx')
us_df.to_excel(writer, sheet_name='US Portfolio')
foreign_df.to_excel(writer, sheet_name='Foreign Portfolio')
writer.save()
