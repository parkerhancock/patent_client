# %% [markdown]
# # Examiner Monitor
#
# This notebook shows how patent_client can be used to examine what is on a particular examiner's docket, and some simple statistics for a particular examiner.
#
# The input to this will just be an application that we know the examiner is handling - like for example a case we just got an Office Action from.

# %%
app_no = '13629597'

# %%
from patent_client_plus import USApplication
apps = USApplication.objects.filter(app_exam_name="ZHEN, LI B", app_grp_art_number=2121)
len(apps)
# Out:
# 433

# %% [markdown]
# Next, we'll do our standard imports, query the USApplication object for that application, and retreive the examiner's name

# %%
import pandas as pd
import numpy as np
from patent_client_plus import USApplication

app = USApplication.objects.get(app_no)
examiner = app.app_exam_name
print(f'The examiner for {app_no} is {examiner}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f660968fddc6> in <module>
#       3 from patent_client_plus import USApplication
#       4
# ----> 5 app = USApplication.objects.get(app_no)
#       6 examiner = app.app_exam_name
#       7 print(f'The examiner for {app_no} is {examiner}')
#
# NameError: name 'app_no' is not defined

# %% [markdown]
# Then, we'll go and retreive all the cases that this examiner has ever handled by searching USApplication for all applications listing the same examiner, and then populate a subset of that data into a Pandas DataFrame.
#
# *NOTE:* Because the USApplication object is lazy, this might take a minute - patent_client is now retrieving the application data

# %%
examiners_applications = USApplication.objects.filter(app_exam_name="ZHEN, LI B", app_grp_art_number=2121)
fields = ['appl_id', 'app_filing_date', 'patent_title', 'patent_number', 'app_status', 'app_status_date']
exam_df = pd.DataFrame.from_records(examiners_applications.values(*fields))
exam_df.head()
# Out:
#     appl_id app_filing_date  \
# 0  16104054      2018-08-16
# 1  16184946      2018-11-08
# 2  16189791      2018-11-13
# 3  16001858      2018-06-06
# 4  16021147      2018-06-28
#
#                                         patent_title patent_number  \
# 0  ARTIFICIAL INTELLIGENCE SYSTEM CONFIGURED TO M...          None
# 1           Determining Preferential Device Behavior          None
# 2  METHODS OF AND SYSTEMS FOR SELECTING AND PRESE...          None
# 3    DETERMINING CONTROL ACTIONS OF DECISION MODULES          None
# 4                 INTERFACE TO LEAKY SPIKING NEURONS          None
#
#                                   app_status app_status_date
# 0  Docketed New Case - Ready for Examination      2019-06-12
# 1  Docketed New Case - Ready for Examination      2019-06-12
# 2  Docketed New Case - Ready for Examination      2019-06-12
# 3  Docketed New Case - Ready for Examination      2019-06-12
# 4  Docketed New Case - Ready for Examination      2019-06-12

# %%
def check_track_one(app):
    return {
        "appl_id": app.appl_id,
        "track_one": len(list(t for t in app.transaction_history if "Track 1 Request" in t.description)) > 0
    }

track_one = pd.DataFrame.from_records(map(check_track_one, examiners_applications))

# %%
track_one[track_one.track_one == True]
# Out:
# Empty DataFrame
# Columns: [appl_id, track_one]
# Index: []

# %% [markdown]
# ## Simple Lookups
#
# Now that we have all the Examiner's cases, we want to take a peek at what the Examiner is working on. To do that, we'll make a list of application status names that we're interested in - those that indicate that the Examiner is still working on the case and the case isn't abandoned, allowed, or awaiting a first office action

# %%
active_pros_statuses = [
    'Advisory Action Mailed',
    'Board of Appeals Decision Rendered',
    'Non Final Action Mailed',
    'Response after Final Action Forwarded to Examiner',
    'Response to Non-Final Office Action Entered and Forwarded to Examiner',
    'Final Rejection Mailed',
]

active_df = exam_df[exam_df['app_status'].isin(active_pros_statuses)]
active_df.head()
# Out:
#       appl_id app_filing_date  \
# 75   14874201      2015-10-02
# 79   15208020      2016-07-12
# 117  15134868      2016-04-21
#
#                                           patent_title patent_number  \
# 75                  PROBABILISTIC MESSAGE DISTRIBUTION          None
# 79      VECTOR OPERATORS FOR DISTRIBUTIONAL ENTAILMENT          None
# 117  SYSTEM AND METHOD FOR FORECASTING LEAKS IN A F...          None
#
#                   app_status app_status_date
# 75    Final Rejection Mailed      2019-04-09
# 79   Non Final Action Mailed      2019-02-14
# 117  Non Final Action Mailed      2019-01-09

# %% [markdown]
# Maybe we're trying to predict when an Examiner might get to a particular case. To do that, we can use a Pandas filter to select all the cases that have the status "Docketed New Case - Ready for Examination"

# %%
docket_df = exam_df[exam_df['app_status'] == 'Docketed New Case - Ready for Examination']
docket_df.head()
# Out:
#     appl_id app_filing_date  \
# 0  16104054      2018-08-16
# 1  16184946      2018-11-08
# 2  16189791      2018-11-13
# 3  16001858      2018-06-06
# 4  16021147      2018-06-28
#
#                                         patent_title patent_number  \
# 0  ARTIFICIAL INTELLIGENCE SYSTEM CONFIGURED TO M...          None
# 1           Determining Preferential Device Behavior          None
# 2  METHODS OF AND SYSTEMS FOR SELECTING AND PRESE...          None
# 3    DETERMINING CONTROL ACTIONS OF DECISION MODULES          None
# 4                 INTERFACE TO LEAKY SPIKING NEURONS          None
#
#                                   app_status app_status_date
# 0  Docketed New Case - Ready for Examination      2019-06-12
# 1  Docketed New Case - Ready for Examination      2019-06-12
# 2  Docketed New Case - Ready for Examination      2019-06-12
# 3  Docketed New Case - Ready for Examination      2019-06-12
# 4  Docketed New Case - Ready for Examination      2019-06-12

# %%
docket_df
# Out:
#       appl_id app_filing_date  \
# 412  15325655      2017-01-11
# 417  15406542      2017-01-13
# 415  15412233      2017-01-23
# 413  15414514      2017-01-24
# 402  15414407      2017-01-24
# 354  15418403      2017-01-27
# 398  15418875      2017-01-30
# 418  15419517      2017-01-30
# 414  15420640      2017-01-31
# 407  15425924      2017-02-06
# 399  15502764      2017-02-08
# 416  15442142      2017-02-24
# 380  15507168      2017-02-27
# 395  15444030      2017-02-27
# 404  15443221      2017-02-27
# 409  15445687      2017-02-28
# 408  15444923      2017-02-28
# 405  15447956      2017-03-02
# 355  15508129      2017-03-02
# 310  15510418      2017-03-10
# 403  15460247      2017-03-16
# 410  15461748      2017-03-17
# 397  15463774      2017-03-20
# 228  15464268      2017-03-20
# 411  15465682      2017-03-22
# 406  15468034      2017-03-23
# 361  15479699      2017-04-05
# 362  15483118      2017-04-10
# 363  15489560      2017-04-17
# 373  15495804      2017-04-24
# ..        ...             ...
# 18   16221189      2018-12-14
# 54   16221410      2018-12-14
# 55   16226069      2018-12-19
# 20   16225278      2018-12-19
# 19   16225003      2018-12-19
# 56   16231124      2018-12-21
# 57   16232387      2018-12-26
# 58   16236385      2018-12-29
# 80   16237306      2018-12-31
# 59   16239797      2019-01-04
# 60   16241456      2019-01-07
# 81   16242304      2019-01-08
# 21   16243600      2019-01-09
# 22   16244510      2019-01-10
# 61   16245425      2019-01-11
# 23   16259534      2019-01-28
# 62   16266301      2019-02-04
# 63   16267285      2019-02-04
# 64   16267317      2019-02-04
# 24   16268815      2019-02-06
# 65   16271195      2019-02-08
# 66   16272769      2019-02-11
# 25   16274494      2019-02-13
# 67   16275402      2019-02-14
# 68   16278670      2019-02-18
# 26   16280872      2019-02-20
# 69   16280317      2019-02-20
# 27   16281246      2019-02-21
# 28   16283021      2019-02-22
# 70   16282550      2019-02-22
#
#                                           patent_title patent_number  \
# 412                          IMMUNE RECOGNITION MOTIFS          None
# 417          Systems and Methods for Predictive Coding          None
# 415      ANALYSIS DEVICE, ANALYSIS METHOD, AND PROGRAM          None
# 413  SYSTEM AND METHOD FOR PARALLELIZING CONVOLUTIO...          None
# 402                 FOOD PREPARATION SYSTEM AND METHOD          None
# 354  Decision Making and Planning/Prediction System...          None
# 398  SYSTEMS AND METHODS FOR SEMANTIC CONCEPT DEFIN...          None
# 418  SYSTEMS AND METHODS FOR CONSTRUCTING AND APPLY...          None
# 414  BIAS ESTIMATION APPARATUS AND METHOD AND FAILU...          None
# 407  DIRECT INVERSE REINFORCEMENT LEARNING WITH DEN...          None
# 399  METHODS AND SYSTEMS FOR BASE MAP AND INFERENCE...          None
# 416  METHOD AND APPARATUS FOR LABELING TRAINING SAM...          None
# 380  VIBRATION SIGNATURES FOR PROGNOSTICS AND HEALT...          None
# 395  COMPUTER IMPLEMENTED SYSTEM FOR AUTOMATING THE...          None
# 404                           SCALABLE CURATION SYSTEM          None
# 409  DATA PATTERN ANALYSIS USING OPTIMIZED DETERMIN...          None
# 408                   Recommending Native Applications          None
# 405  SYSTEM, METHOD AND COMPUTER PROGRAM PRODUCT FO...          None
# 355  METHOD AND SYSTEM FOR HOURS-AHEAD AND DAY-AHEA...          None
# 310  APPARATUS AND METHOD FOR ENSEMBLES OF KERNEL R...          None
# 403  METHOD AND DEVICE FOR PREDICTING INFORMATION P...          None
# 410  SYSTEM AND METHOD FOR A RECURSIVE CORTICAL NET...          None
# 397    GENERATING PREFERENCE INDICES FOR IMAGE CONTENT          None
# 228      PREDICTIVE INSTANCE SUSPENSION AND RESUMPTION          None
# 411  Extensible Validation Framework for Question a...          None
# 406          NETWORK-PROBABILITY RECOMMENDATION SYSTEM          None
# 361             DYNAMICALLY DETERMINING RELEVANT CASES          None
# 362          METHOD AND SYSTEM TO PROVIDE RELATED DATA          None
# 363        METHOD OF AUTOMATED DISCOVERY OF NEW TOPICS          None
# 373  FEATURE DETECTION APPARATUS AND METHODS FOR TR...          None
# ..                                                 ...           ...
# 18   Method and System for Analyzing Data in a Data...          None
# 54   SYSTEMS AND METHODS FOR DETERMINING THE IMPACT...          None
# 55   COMPUTER IMPLEMENTED SYSTEM AND METHOD FOR ASS...          None
# 20   Optical coherence tomography array based subde...          None
# 19   Electrical Connection of Control Circuit Card ...          None
# 56              FEATURE PROCESSING TRADEOFF MANAGEMENT          None
# 57   VOLTAGE CONTROLLED HIGHLY LINEAR RESISTIVE ELE...          None
# 58    SYSTEM FOR MANAGING AN INSTRUCTURE WITH SECURITY          None
# 80   CLASSIFICATION OF MEMBERS IN A SOCIAL NETWORKI...          None
# 59   DATABASE UTILIZING SPATIAL PROBABILITY MODELS ...          None
# 60        Behavioral Prediction for Targeted End Users          None
# 81   SYSTEM AND METHOD FOR PROVIDING DISTRIBUTED IN...          None
# 21                            LABELING/NAMES OF THEMES          None
# 22             SYSTEMS AND METHODS FOR DATA MANAGEMENT          None
# 61   FOUR-PORT CIRCULATOR WITH FREQUENCY CONVERSION...          None
# 23   Systems and Methods for Predicting Metabolic a...          None
# 62   LDMOS Transistors And Associated Systems And M...          None
# 63   NEURAL NETWORK APPLICATIONS IN RESOURCE CONSTR...          None
# 64   NEURAL NETWORK APPLICATIONS IN RESOURCE CONSTR...          None
# 24   INFORMATION PROCESSING APPARATUS, PROGRAM, AND...          None
# 65   Cognitive Information Processing System Enviro...          None
# 66   QUICK PATH TO TRAIN, SCORE, AND OPERATIONALIZE...          None
# 25   POWER SUPPLY INCLUDING BI-DIRECTIONAL DC CONVE...          None
# 67   INCIDENT PREDICTION AND RESPONSE USING DEEP LE...          None
# 68             FUTURE EVENT DETECTION AND NOTIFICATION          None
# 26                         ADAPTIVE CONTENT INSPECTION          None
# 69       SYSTEM AND METHODS FOR MIXED-SIGNAL COMPUTING          None
# 27   LEARNING AND DEPLOYMENT OF ADAPTIVE WIRELESS C...          None
# 28   CONVOLUTIONAL NEURAL NETWORK OPTIMIZATION MECH...          None
# 70                  Secure Voice Communications System          None
#
#                                     app_status app_status_date
# 412  Docketed New Case - Ready for Examination      2017-04-03
# 417  Docketed New Case - Ready for Examination      2017-03-06
# 415  Docketed New Case - Ready for Examination      2017-03-06
# 413  Docketed New Case - Ready for Examination      2017-03-06
# 402  Docketed New Case - Ready for Examination      2017-05-09
# 354  Docketed New Case - Ready for Examination      2017-12-15
# 398  Docketed New Case - Ready for Examination      2017-06-05
# 418  Docketed New Case - Ready for Examination      2017-03-06
# 414  Docketed New Case - Ready for Examination      2017-03-06
# 407  Docketed New Case - Ready for Examination      2017-04-03
# 399  Docketed New Case - Ready for Examination      2017-05-22
# 416  Docketed New Case - Ready for Examination      2017-03-06
# 380  Docketed New Case - Ready for Examination      2017-08-01
# 395  Docketed New Case - Ready for Examination      2017-06-27
# 404  Docketed New Case - Ready for Examination      2017-04-03
# 409  Docketed New Case - Ready for Examination      2017-04-03
# 408  Docketed New Case - Ready for Examination      2017-04-03
# 405  Docketed New Case - Ready for Examination      2017-04-03
# 355  Docketed New Case - Ready for Examination      2017-11-21
# 310  Docketed New Case - Ready for Examination      2018-03-13
# 403  Docketed New Case - Ready for Examination      2017-04-18
# 410  Docketed New Case - Ready for Examination      2017-04-03
# 397  Docketed New Case - Ready for Examination      2017-06-05
# 228  Docketed New Case - Ready for Examination      2018-03-28
# 411  Docketed New Case - Ready for Examination      2017-04-03
# 406  Docketed New Case - Ready for Examination      2017-04-03
# 361  Docketed New Case - Ready for Examination      2017-08-28
# 362  Docketed New Case - Ready for Examination      2017-08-28
# 363  Docketed New Case - Ready for Examination      2017-08-28
# 373  Docketed New Case - Ready for Examination      2017-08-15
# ..                                         ...             ...
# 18   Docketed New Case - Ready for Examination      2019-06-12
# 54   Docketed New Case - Ready for Examination      2019-06-12
# 55   Docketed New Case - Ready for Examination      2019-06-12
# 20   Docketed New Case - Ready for Examination      2019-06-12
# 19   Docketed New Case - Ready for Examination      2019-06-12
# 56   Docketed New Case - Ready for Examination      2019-06-12
# 57   Docketed New Case - Ready for Examination      2019-06-12
# 58   Docketed New Case - Ready for Examination      2019-06-12
# 80   Docketed New Case - Ready for Examination      2019-02-06
# 59   Docketed New Case - Ready for Examination      2019-06-12
# 60   Docketed New Case - Ready for Examination      2019-06-12
# 81   Docketed New Case - Ready for Examination      2019-02-06
# 21   Docketed New Case - Ready for Examination      2019-06-12
# 22   Docketed New Case - Ready for Examination      2019-06-12
# 61   Docketed New Case - Ready for Examination      2019-06-12
# 23   Docketed New Case - Ready for Examination      2019-06-12
# 62   Docketed New Case - Ready for Examination      2019-06-12
# 63   Docketed New Case - Ready for Examination      2019-06-12
# 64   Docketed New Case - Ready for Examination      2019-06-12
# 24   Docketed New Case - Ready for Examination      2019-06-12
# 65   Docketed New Case - Ready for Examination      2019-06-12
# 66   Docketed New Case - Ready for Examination      2019-06-12
# 25   Docketed New Case - Ready for Examination      2019-06-12
# 67   Docketed New Case - Ready for Examination      2019-06-12
# 68   Docketed New Case - Ready for Examination      2019-06-12
# 26   Docketed New Case - Ready for Examination      2019-06-12
# 69   Docketed New Case - Ready for Examination      2019-06-12
# 27   Docketed New Case - Ready for Examination      2019-06-12
# 28   Docketed New Case - Ready for Examination      2019-06-12
# 70   Docketed New Case - Ready for Examination      2019-06-12
#
# [412 rows x 6 columns]

# %% [markdown]
# Then we can use a simple function to count how many cases are ahead of ours, first by sorting by filing date, then counting how many cases down our application is:

# %%
docket_df = docket_df.sort_values('app_filing_date', ascending=True)

counter = 0

for i, row in docket_df.iterrows():
    if row['appl_id'] == app_no:
        break
    counter += 1

print(f"There are {counter} cases ahead of {app_no} on Examiner {examiner}'s Docket")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cf1b5611b738> in <module>
#       4
#       5 for i, row in docket_df.iterrows():
# ----> 6     if row['appl_id'] == app_no:
#       7         break
#       8     counter += 1
#
# NameError: name 'app_no' is not defined

# %% [markdown]
# ## Statistical Analysis
#
# Maybe we want some more detailed information. Things like average pendency, overall case load, etc. Let's do some of those statistics now.
#
# First, we'll take a look at the examiner's entire docket, bucketed by years, to get a general sense for the Examiner's workflow and case dispositions. To start, we'll add a column that will classify a case as either "Patented", "Abandoned", or "Pending". To do that, we'll use the Pandas "apply" function. If the case has a patent number, we'll categorize it as "Patented." This is better than looking at status, because the case might have lapsed for failure to pay maintenace fees. Then we'll look at the status and see if the word "abandoned" appears in it. If so, we can be reasonably sure the case has been abandoned. If it doesn't fit in either category, then the case is still pending.

# %%
def final_disposition(row):
    row['year'] = row['app_filing_date'].year
    if row['patent_number']:
        row['final'] = 'Patented'
    elif 'abandon' in str(row['app_status']).lower():
        row['final'] = 'Abandoned'
    else:
        row['final'] = 'Pending'
    return row
        
final_df = exam_df[~exam_df['appl_id'].str.contains('PCT')].apply(final_disposition, axis=1)

final_df.head()
# Out:
#     appl_id app_filing_date  \
# 0  13046650      2011-03-11
# 1  13256177      2011-09-12
# 2  13273818      2011-10-14
# 3  13280377      2011-10-25
# 4  13323676      2011-12-12
#
#                                         patent_title patent_number  \
# 0  LEARNING ROAD FEATURE DELAY TIMES BASED ON AGG...       9257042
# 1  Method For Optimizing The Power Consumption Of...          None
# 2  METHOD AND APPARATUS FOR DETERMINING THE RELAT...       8990002
# 3                            RANGE DISPLAY APPARATUS          None
# 4  RELAY FUSION DETECTING TECHNIQUE FOR HIGH VOLT...          None
#
#                                           app_status app_status_date  year  \
# 0                                      Patented Case      2016-01-20  2011
# 1  Abandoned -- Failure to Respond to an Office A...      2014-08-21  2011
# 2                                      Patented Case      2015-03-04  2011
# 3  Abandoned -- Failure to Respond to an Office A...      2015-05-31  2011
# 4  Abandoned -- Failure to Respond to an Office A...      2014-06-23  2011
#
#        final
# 0   Patented
# 1  Abandoned
# 2   Patented
# 3  Abandoned
# 4  Abandoned

# %% [markdown]
# Now we need to transform the Pandas dataframe into something we can plot. What we would like to have is a dataframe that looks like this:
#
# | Year | Pending | Patented | Expired |
# |------|---------|----------|---------|
# | 2015 | 13      | 12       | 1       |
# | 2016 | 14      | 15       | 15      |
#
# To do that, we're going to need to do an aggregation by year

# %%
# %matplotlib inline

def patented(series):
    return len(list(filter(lambda x: x == '')))

# Group by year, and by final, then create a count of each
result = final_df.groupby(['year', 'final']).agg({'final': 'count'}).rename(columns={'final': 'count'})
result = result.reset_index() # Convert indexes into columns
result = result.pivot(index='year', columns='final', values='count')

result.head()
# Out:
# final  Abandoned  Patented  Pending
# year
# 2011         3.0       2.0      NaN
# 2012         6.0      11.0      NaN
# 2013        19.0      27.0      NaN
# 2014         3.0      26.0      4.0
# 2015         3.0      24.0      6.0

# %% [markdown]
# And now we plot it!

# %%
result.plot.bar(figsize=(10,5))

# %% [markdown]
# ### Average Time to First Action
#
# Maybe we'd like to know how long the Examiner takes from docketing until a first Office Action. To do that, we'll use the transaction information stored on each case. For example, from our original app, the transactions look like this:

# %%
pd.DataFrame.from_records(app.transactions).head()
# Out:
#       code                                        description record_date
# 0    M1551  Payment of Maintenance Fee, 4th Year, Large En...  2018-07-06
# 1     PGM/                 Recordation of Patent Grant Mailed  2015-01-13
# 2  EML_NTR                                 Email Notification  2014-12-25
# 3     WPIR                          Issue Notification Mailed  2014-12-23
# 4     PTAC          Patent Issue Date Used in PTA Calculation  2015-01-13

# %% [markdown]
# First, we need to know all the possible transaction codes. To do that, we can take every case in the examiner's stack, and create a set of code-description tuples

# %%
exam_codes = list(set((r['code'], r['description']) for a in examiners_applications for r in a.transactions))
exam_codes = [{'code': r[0], 'description': r[1]} for r in exam_codes]
codes_df = pd.DataFrame.from_records(exam_codes)
codes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 2 columns):
# code           239 non-null object
# description    239 non-null object
# dtypes: object(2)
# memory usage: 3.8+ KB

# %% [markdown]
# Obviously there are entirely too many possible codes / descriptions to easily pick through in a notebook, so we'll export the spreadsheet to excel for review

# %%
codes_df.to_excel('codes.xlsx')

# %% [markdown]
# After review, it looks like all the relevant codes for a first action by the examiner begin one one of three prefixes - MFA, CT, or MC. And the case is initially docketed with a code 'DOCK'. So let's use this to calculate a time to first office action for each case. Since we're digging deeper into each case, we'll put the applications themselves as a column of the dataframe.

# %%
app_df = pd.DataFrame.from_records({'appl_id': a.appl_id, 'obj': a} for a in examiners_applications if 'PCT' not in a.appl_id)
app_df.head()
# Out:
#     appl_id                                obj
# 0  13046650  <USApplication(appl_id=13046650)>
# 1  13256177  <USApplication(appl_id=13256177)>
# 2  13273818  <USApplication(appl_id=13273818)>
# 3  13280377  <USApplication(appl_id=13280377)>
# 4  13323676  <USApplication(appl_id=13323676)>

# %% [markdown]
# Now we'll write a function that takes an application, and returns the time to first Examiner's action, measured as days from DOCK to an action by the examiner

# %%
import re
from datetime import datetime

first_action_re=re.compile('^(MFA|CT|MC)')

def time_to_action(row):
    #print(obj.transactions)
    obj = row['obj']
    transactions = sorted(obj.transaction_history, key=lambda x: x.date)
    docketing_date = next(r for r in transactions if r.code == 'DOCK').date
    try:
        first_action = next(r for r in transactions if first_action_re.search(r.code))
    except StopIteration:
        return row
    row['first_action'] = first_action.description
    row['first_action_date'] = first_action.date
    row['docketed_date'] = docketing_date
    
    row['time_to_action'] = (
        first_action.date
        - docketing_date
    ).days
    return row


app_df= app_df.apply(time_to_action, axis=1)
app_df = app_df.astype({'docketed_date': datetime, 'first_action_date': datetime})
app_df.head()
# Out:
#     appl_id docketed_date         first_action first_action_date  \
# 0  13046650    2011-07-05  Non-Final Rejection        2013-03-02
# 1  13256177    2011-10-31  Non-Final Rejection        2013-09-16
# 2  13273818    2012-02-03  Non-Final Rejection        2014-04-07
# 3  13280377    2011-12-06  Non-Final Rejection        2013-11-13
# 4  13323676    2012-02-03  Non-Final Rejection        2013-11-18
#
#                                  obj  time_to_action
# 0  <USApplication(appl_id=13046650)>           606.0
# 1  <USApplication(appl_id=13256177)>           686.0
# 2  <USApplication(appl_id=13273818)>           794.0
# 3  <USApplication(appl_id=13280377)>           708.0
# 4  <USApplication(appl_id=13323676)>           654.0

# %% [markdown]
# And now we can look at the aggregate stats for time to first office action:

# %%
app_df.describe()
# Out:
#        time_to_action
# count      191.000000
# mean       355.476440
# std        199.396532
# min          0.000000
# 25%        201.500000
# 50%        373.000000
# 75%        520.500000
# max        794.000000

# %% [markdown]
# We can also look at the average time by what the response type is:

# %%
app_df.groupby('first_action').describe()
# Out:
#                                           time_to_action              \
#                                                    count        mean
# first_action
# Mail First Action Interview Office Action            1.0  672.000000
# Non-Final Rejection                                179.0  352.737430
# Restriction/Election Requirement                    11.0  371.272727
#
#                                                                             \
#                                                   std    min    25%    50%
# first_action
# Mail First Action Interview Office Action         NaN  672.0  672.0  672.0
# Non-Final Rejection                        199.089566    0.0  201.5  370.0
# Restriction/Election Requirement           198.646969   24.0  219.5  422.0
#
#
#                                              75%    max
# first_action
# Mail First Action Interview Office Action  672.0  672.0
# Non-Final Rejection                        515.5  794.0
# Restriction/Election Requirement           514.0  584.0
