# %%
from bravado.client import SwaggerClient
from bravado.requests_client import RequestsClient

ptab_api = "https://developer.uspto.gov/ptab-api/v2/api-docs"
http_client = RequestsClient(ssl_verify=False)
ptab_client = SwaggerClient.from_url(ptab_api, http_client=http_client)
# Out:
# /Users/parkerhancock/.pyenv/versions/3.7.3/lib/python3.7/site-packages/urllib3/connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
import requests
spec = requests.get("https://developer.uspto.gov/ptab-api/proceedings", verify=False, json={"offset": 10}).json()
spec
# Out:
# /Users/parkerhancock/.pyenv/versions/3.7.3/lib/python3.7/site-packages/urllib3/connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# {'aggregationData': {},
#  'results': [{'proceedingNumber': '1',
#    'proceedingStatusCategory': 'Decision',
#    'proceedingTypeCategory': 'Appeal',
#    'subproceedingTypeCategory': 'REGULAR',
#    'proceedingFilingDate': '10-06-1999',
#    'decisionDate': '07-04-1776',
#    'proceedingLastModifiedDate': '10-07-1999',
#    'appellantApplicationNumberText': '08973113',
#    'respondentApplicationNumberText': '08973113',
#    'appellantPartyName': 'WEUTHEN',
#    'respondentPartyName': 'WEUTHEN',
#    'appellantCounselName': 'SERVILLA WHITNEY LLC/BASF',
#    'appellantPatentOwnerName': 'WEUTHEN',
#    'appellantInventorName': 'WEUTHEN',
# ...

# %%
# Out:
# {'aggregationData': {},
#  'results': [{'proceedingNumber': '1',
#    'proceedingStatusCategory': 'Decision',
#    'proceedingTypeCategory': 'Appeal',
#    'subproceedingTypeCategory': 'REGULAR',
#    'proceedingFilingDate': '10-06-1999',
#    'decisionDate': '07-04-1776',
#    'proceedingLastModifiedDate': '10-07-1999',
#    'appellantApplicationNumberText': '08973113',
#    'respondentApplicationNumberText': '08973113',
#    'appellantPartyName': 'WEUTHEN',
#    'respondentPartyName': 'WEUTHEN',
#    'appellantCounselName': 'SERVILLA WHITNEY LLC/BASF',
#    'appellantPatentOwnerName': 'WEUTHEN',
#    'appellantInventorName': 'WEUTHEN',
#    'appellantTechnologyCenterNumber': '1700',
#    'respondentTechnologyCenterNumber': '1700',
#    'appellantGroupArtUnitNumber': '1751',
#    'respondentGroupArtUnitNumber': '1751'},
#   {'proceedingNumber': '100',
#    'proceedingStatusCategory': 'Decision',
#    'proceedingTypeCategory': 'Appeal',
#    'subproceedingTypeCategory': 'REGULAR',
# ...

# %%
peds_api = "https://ped.uspto.gov/api/v2/api-docs?group=pair-public-api"
peds_client = SwaggerClient.from_url(peds_api, http_client=http_client)
# Out:
# /Users/parkerhancock/.pyenv/versions/3.7.3/lib/python3.7/site-packages/urllib3/connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
peds_client.queries.searchDataUsingPOST(createQueryRequest={

        "searchText": "*:*",

                "fq": ["LAST_MOD_TS:[2019-04-24T00:00:00Z TO *]"],

                "df": "patentTitle",

                "facet": "false"

}
)

# %%
result = _

# %%
result.response()
# Out:
# /Users/parkerhancock/.pyenv/versions/3.7.3/lib/python3.7/site-packages/urllib3/connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
response = _

# %%
response.result
# Out:
# {'queryResults': {'indexLastUpdatedDate': 'Mon Aug 05 16:49:28 EDT 2019',
#   'searchResponse': {'responseHeader': {'zkConnected': True,
#     'status': 0,
#     'QTime': 164},
#    'response': {'numFound': 1944927,
#     'start': 0,
#     'docs': [{'applId': '16481220',
#       'publicInd': 'N',
#       'APP_IND': '1',
#       'inventorName': 'Guillermo A. Morales',
#       'inventorNameFacet': 'Guillermo A. Morales',
#       'appLocation': 'ELECTRONIC',
#       'id': '16481220',
#       'applIdStr': '16481220',
#       'appl_id_txt': '16481220',
#       'LAST_MOD_TS': '2019-07-31T09:41:48Z',
#       'transactions': [{'recordDate': '2019-07-26 00:00:00',
#         'code': 'WIDS',
#         'description': 'Information Disclosure Statement (IDS) Filed'},
#        {'recordDate': '2019-07-26 00:00:00',
#         'code': 'WIDS',
#         'description': 'Information Disclosure Statement (IDS) Filed'},
#        {'recordDate': '2019-07-26 00:00:00',
#         'code': 'L194',
# ...
